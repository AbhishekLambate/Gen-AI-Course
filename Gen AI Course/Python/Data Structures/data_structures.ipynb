# %% [markdown]
# ## Data Structures

# %% [markdown]
# ##### Data structures are being used for storing the data in the structured format so that we can access the data and along with that we can perform all of the operations with these data structures that we can perform in the case of databases as well like CRUD (create, read, update , delete) operations

# %% [markdown]
# ### Types of data structures in python:
# #### 1. List
# #### 2. Tuple
# #### 3. Set
# #### 4. Dictionary

# %% [markdown]
# ### The differnt types of data sturctures differs on this basis that in which specific format we can store our data
