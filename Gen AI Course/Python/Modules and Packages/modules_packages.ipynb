# %% [markdown]
# ## Modules and Packages

# %% [markdown]
# ### Module -> A module in python is simply a file containing python code (function, classes or variables) that can be imported and used in other programs

# %% [markdown]
# ### Numpy -> Numpy module is going to help us out with applying scientific calculations on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared with the list
#
# ### We can do it in numpy just because numpy is having the collection of functions and attributes which can help us to work efficiently with the array

# %% [markdown]
# ### Pandas -> Pandas we can use when we are going to work with the dataset for cleaning, pre processing, EDA (Exploratory Data Analysis), analysis with plotting as well

# %%
print("hi")
# Out:
# hi

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
''' Module:
    
1. A module helps in code organization
2. It promotes reusability
3. It keeps the code clean and manageable
'''
# Out:
# ' Module:\n\n1. A module helps in code organization\n2. It promotes reusability\n3. It keeps the code clean and manageable\n'

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import sys
print(sys.executable)
# Out:
# /home/ubuntu/Documents/Abhi_Important/Gen-AI-Course/Gen AI Course/Python/venv/bin/python

# %%
# !pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 24.5 MB/s  0:00:00m0:00:0100:01
# ...

# %%
import numpy

# %%
items=[1,2,3,4]
arrays=numpy.array(items)
print(type(arrays))
print(arrays)
# Out:
# <class 'numpy.ndarray'>
# [1 2 3 4]

# %% [markdown]
# ## Create own library or Module

# %% [markdown]
# ### __init__.py is a file that has to be their inside package folder and this __init__.py file helps us out in defining our package and initializing their namespaces
#
# ### __init__.py file can remain empty and its completely fine but this file has to be their when we will be creating  our new packages into the package folder

# %%
from package_folder.mathematics import addition

addition(4,5)
# Out:
# 9

# %%
from package_folder.mathematics import *

division(2,0)
# Out:
# 'Enter the valid value'

# %%
division(4,2)
# Out:
# 2.0

# %%
from package_folder.subpackage.sum import *

addition(1,2,3)
# Out:
# 6
