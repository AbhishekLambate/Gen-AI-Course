# %% [markdown]
# ## Streamlit

# %% [markdown]
# ### Streamlit is an open source Python library used to build beautiful, iteractive web applications for data science and machine learning with minimal efforts.

# %% [markdown]
# ### Why to use streamlit
# ### Easy to use
# ### Fast development
# ### Interactive UI elements -> Buttons, sliders, text inputs, charts, etc
# ### Great for data science -> Supports Pandas, Matplotlib, Plotly and other libraries
# ### Deployment  is easy
