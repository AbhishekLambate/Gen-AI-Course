# %% [markdown]
# ## what is python language?

# %% [markdown]
# ### python is a type of programming language which we can use for communicationg with computers or technology

# %% [markdown]
# ## Syntax for python

# %% [markdown]
# syntax refers to set of rules that defines the combination of symbols that are considered to be correctly structured programs in a language

# %% [markdown]
# ## Semantics of python

# %% [markdown]
# Semantics of python language refers to meanings or interpretation of symbols, characters and commands in a language. It is about what the code is suppose to do when it runs.

# %% [markdown]
# ## Syntax Rules

# %% [markdown]
# ### 1. case sensitive

# %%
name="Abhishek"
Name="Abhishek"
name==Name
# Out:
# True

# %%
name="Abhishek"
Name="abhishek"
name==Name
# Out:
# False

# %% [markdown]
# ## Indentation in python

# %% [markdown]
# in other programing languages we use brases for grouping of statements.
# in python, we use indentation for proper grouping of statements as the proper arguments of statements with proper spacing in the statements within a block.

# %%
age=int(input("Enter your age: "))
if age > 18 :
    print("You are an adult")
# Out:
# You are an adult

# %%
a=1+2+3+4+5
print(a)
# Out:
# 15

# %%
1+2+3+4+5+\
    6+7
# Out:
# 28

# %% [markdown]
# ### Line Continuation -> we can use Backslash (" \ ") for continuing the statemnnt on the next line

# %% [markdown]
# ## Multiple statements in single line

# %%
a=5 ; b=4 ; c=2
print(a)
print(b)
print(c)
# Out:
# 5
# 4
# 2
