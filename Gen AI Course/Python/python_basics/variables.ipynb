# %% [markdown]
# ## Variables

# %% [markdown]
# ### variables are the elements in python that can be used for storing data into it or values into it or they can be refered as containers as well
# ### variables as per its name, data can vary that we are going to store into it and once we have delared variable we can vary the value stored in it.

# %%
name = "Abhishek"
age = 24
height = 5.4
is_true = True

# %%
age
# Out:
# 24

# %% [markdown]
# ## variables naming conventions

# %% [markdown]
# 1.Variable names must be descriptive :
#     age=23
#     name="Abhishek"
# 2.They must start with letter or underscore and can contain lettern number and underscore
#     name1="Abhishek"
#     _name="Abhishek"
# 3.Variables are case sensitive
#     name and Name are treat as different

# %%
name = "Abhishek"
age = 24
height = 5.4
is_true = True

print(type(age))
# Out:
# <class 'int'>

# %%
''' 
Every type casting is not possible. For example, we cannot convert a string to an integer if the string does not represent a valid integer.
'''
name="23"
name=int(name)
print(type(name))
# Out:
# <class 'int'>

# %% [markdown]
# ## Input function only takes the input in a string format until and unless we are not going to eplicitly take the input in integer or other format

# %%
# building simple calculator

value1=int(input("Enter first value: "))
value2=int(input("Enter second value: "))
print("The addition of values is: ", value1+value2)
print("The substraction of values is: ", value2-value1)
print("The product of values is: ", value1*value2)
print("The division of values is: ", value2/value1)
# Out:
# The addition of values is:  12
# The substraction of values is:  8
# The product of values is:  20
# The division of values is:  5.0
